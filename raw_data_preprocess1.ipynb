# %%
import numpy as np
import pandas as pd
import time

# %%
data_part1 = pd.read_csv('../data/meinian_round1_data_part1_20180408.txt', sep='$')
data_part2 = pd.read_csv('../data/meinian_round1_data_part2_20180408.txt', sep='$')

# %%
data = pd.concat([data_part1, data_part2])
print(data.shape)
# Out:
# (8104368, 3)

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (8052058, 3)

# %%
# 把table_id相同的体检项，全部保留;堆叠为同一行保存，以 “;” 分隔
# 多使用apply函数、map函数，和逐行代码处理相比，速度更快，而且代码更加简洁
start = time.time()
data_keep_all = data.groupby(['vid','table_id'],as_index=False).apply(lambda x:"$".join(map(str, x['field_results'])))
# 返回一个series
data_keep_all = pd.DataFrame(data_keep_all,columns=['field_results'])
end = time.time()
print('time used: ', end - start)
print('shape of data_keep_all: ', data_keep_all.shape)
# time used:  511.33177399635315
# shape of data_keep_all:  (7820997, 1)
# Out:
# time used:  504.62600350379944
# shape of data_keep_all:  (7820997, 1)

# %%
# data_keep_all.info()

# %%
# data_keep_all.to_csv('../tmp/data_keep_all.csv', index=False, encoding='utf-8')
# data_keep_all.head()

# %%
# data_keep_all = pd.read_csv('../tmp/data_keep_all.csv', encoding='utf-8')
# data_keep_all.head()

# %%
data_keep_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 7820997 entries, (000330ad1f424114719b7525f400660b, 0101) to (fffda084a188b379e403f64e62c2adf5, A302)
# Data columns (total 1 columns):
# field_results    object
# dtypes: object(1)
# memory usage: 104.9+ MB

# %%
data_keep_all.head()
# Out:
#                                                                                field_results
# vid                              table_id
# 000330ad1f424114719b7525f400660b 0101      双侧甲状腺大小形态正常，包膜光整，实质回声均匀，光点稍粗，未见明显异常回声。CDFI：血流显...
#                                  0102      甲状腺彩超（含颈部淋巴细胞）未发现明显异常$前列腺:前列腺稍大膀胱、双侧输尿管未发现明显异常...
#                                  0113                         肝脏大小、形态正常，包膜光整，肝内血管走行较清晰，回声均匀。
#                                  0114                          胆囊大小、形态正常，囊壁光整，囊腔内透声好，胆总管无扩张。
#                                  0115                          胰腺大小、形态正常，边缘规整，内部回声均匀，胰管未见扩张。

# %%
#  转化为 行列格式
data_fmt_all = data_keep_all.unstack(fill_value=np.nan)
data_fmt_all.head()
# Out:
#                                  field_results  \
# table_id                                004997
# vid
# 000330ad1f424114719b7525f400660b           NaN
# 000381f0069cbf7537e6aac8923034ae           NaN
# 0003848ebd8d8163603760d53d975693           NaN
# 000401cbf304d5a8bd862a81bacfa494           NaN
# 00044a586c249c05f0969e45ef03ab9d           NaN
#
#                                                                                      \
# table_id                                                                       0101
# vid
# 000330ad1f424114719b7525f400660b  双侧甲状腺大小形态正常，包膜光整，实质回声均匀，光点稍粗，未见明显异常回声。CDFI：血流显...
# 000381f0069cbf7537e6aac8923034ae                                                NaN
# 0003848ebd8d8163603760d53d975693  双侧乳腺腺体层增厚,内部结构紊乱,回声不均，未见异常血流。$双侧甲状腺大小形态正常，包膜尚完...
# 000401cbf304d5a8bd862a81bacfa494  双侧乳腺腺体层轻度增厚,内部结构稍紊乱,回声欠均匀，CDFI：未见异常血流。$双侧甲状腺形态...
# 00044a586c249c05f0969e45ef03ab9d  双侧乳腺腺体层增厚,内部结构紊乱,回声不均，右侧内可见一低回声区，范围约21×15mm，边界...
#
#                                                                                      \
# table_id                                                                       0102
# vid
# 000330ad1f424114719b7525f400660b  甲状腺彩超（含颈部淋巴细胞）未发现明显异常$前列腺:前列腺稍大膀胱、双侧输尿管未发现明显异常...
# 000381f0069cbf7537e6aac8923034ae  左肾、右肾、膀胱、双侧输尿管未发现明显异常$子宫:绝经后子宫左附件、右附件未发现明显异常$肝...
# 0003848ebd8d8163603760d53d975693  左肾、右肾、膀胱、双侧输尿管未发现明显异常$双侧乳腺小叶增生$甲状腺双叶回声不均匀,建议甲功...
# 000401cbf304d5a8bd862a81bacfa494  肝:脂肪肝（轻度）胆、胰、脾、左肾、右肾未发现明显异常$双侧乳腺轻度增生$子宫:宫颈囊肿（多...
# 00044a586c249c05f0969e45ef03ab9d  双侧乳腺小叶增生右乳腺低回声区，考虑结节,建议医院进一步检查$肝、胆、胰、脾未发现明显异常$...
#
#                                                                      ...    \
# table_id                         0104 0105 0106 0107 0108 0109 0111  ...
# vid                                                                  ...
# 000330ad1f424114719b7525f400660b  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 000381f0069cbf7537e6aac8923034ae  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 0003848ebd8d8163603760d53d975693  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 000401cbf304d5a8bd862a81bacfa494  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 00044a586c249c05f0969e45ef03ab9d  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
#
#                                                                             \
# table_id                         Y19001 Y19004 Y29001 Y29002 Y29003 Y29004
# vid
# 000330ad1f424114719b7525f400660b    NaN    NaN    NaN    NaN    NaN    NaN
# 000381f0069cbf7537e6aac8923034ae    NaN    NaN    NaN    NaN    NaN    NaN
# 0003848ebd8d8163603760d53d975693    NaN    NaN    NaN    NaN    NaN    NaN
# 000401cbf304d5a8bd862a81bacfa494    NaN    NaN    NaN    NaN    NaN    NaN
# 00044a586c249c05f0969e45ef03ab9d    NaN    NaN    NaN    NaN    NaN    NaN
#
#
# table_id                         Y29005 Y29021 Y29058 Y79001
# vid
# 000330ad1f424114719b7525f400660b    NaN    NaN    NaN    NaN
# 000381f0069cbf7537e6aac8923034ae    NaN    NaN    NaN    NaN
# 0003848ebd8d8163603760d53d975693    NaN    NaN    NaN    NaN
# 000401cbf304d5a8bd862a81bacfa494    NaN    NaN    NaN    NaN
# 00044a586c249c05f0969e45ef03ab9d    NaN    NaN    NaN    NaN
#
# [5 rows x 2795 columns]

# %%
data_fmt_all.columns.levels[0]
# Out:
# Index(['field_results'], dtype='object')

# %%
data_fmt_all.columns.levels[1]
# Out:
# Index(['004997', '0101', '0102', '0104', '0105', '0106', '0107', '0108',
#        '0109', '0111',
#        ...
#        'Y19001', 'Y19004', 'Y29001', 'Y29002', 'Y29003', 'Y29004', 'Y29005',
#        'Y29021', 'Y29058', 'Y79001'],
#       dtype='object', name='table_id', length=2795)

# %%
# 去除level[0]
data_fmt_all.columns = data_fmt_all.columns.droplevel(level=0)
print(data_fmt_all.shape)
# (57298, 2795) 共有2795个特征值
# Out:
# (57298, 2795)

# %%
data_fmt_all.head()
# Out:
# table_id                         004997  \
# vid
# 000330ad1f424114719b7525f400660b    NaN
# 000381f0069cbf7537e6aac8923034ae    NaN
# 0003848ebd8d8163603760d53d975693    NaN
# 000401cbf304d5a8bd862a81bacfa494    NaN
# 00044a586c249c05f0969e45ef03ab9d    NaN
#
# table_id                                                                       0101  \
# vid
# 000330ad1f424114719b7525f400660b  双侧甲状腺大小形态正常，包膜光整，实质回声均匀，光点稍粗，未见明显异常回声。CDFI：血流显...
# 000381f0069cbf7537e6aac8923034ae                                                NaN
# 0003848ebd8d8163603760d53d975693  双侧乳腺腺体层增厚,内部结构紊乱,回声不均，未见异常血流。$双侧甲状腺大小形态正常，包膜尚完...
# 000401cbf304d5a8bd862a81bacfa494  双侧乳腺腺体层轻度增厚,内部结构稍紊乱,回声欠均匀，CDFI：未见异常血流。$双侧甲状腺形态...
# 00044a586c249c05f0969e45ef03ab9d  双侧乳腺腺体层增厚,内部结构紊乱,回声不均，右侧内可见一低回声区，范围约21×15mm，边界...
#
# table_id                                                                       0102  \
# vid
# 000330ad1f424114719b7525f400660b  甲状腺彩超（含颈部淋巴细胞）未发现明显异常$前列腺:前列腺稍大膀胱、双侧输尿管未发现明显异常...
# 000381f0069cbf7537e6aac8923034ae  左肾、右肾、膀胱、双侧输尿管未发现明显异常$子宫:绝经后子宫左附件、右附件未发现明显异常$肝...
# 0003848ebd8d8163603760d53d975693  左肾、右肾、膀胱、双侧输尿管未发现明显异常$双侧乳腺小叶增生$甲状腺双叶回声不均匀,建议甲功...
# 000401cbf304d5a8bd862a81bacfa494  肝:脂肪肝（轻度）胆、胰、脾、左肾、右肾未发现明显异常$双侧乳腺轻度增生$子宫:宫颈囊肿（多...
# 00044a586c249c05f0969e45ef03ab9d  双侧乳腺小叶增生右乳腺低回声区，考虑结节,建议医院进一步检查$肝、胆、胰、脾未发现明显异常$...
#
# table_id                         0104 0105 0106 0107 0108 0109 0111  ...    \
# vid                                                                  ...
# 000330ad1f424114719b7525f400660b  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 000381f0069cbf7537e6aac8923034ae  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 0003848ebd8d8163603760d53d975693  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 000401cbf304d5a8bd862a81bacfa494  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 00044a586c249c05f0969e45ef03ab9d  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
#
# table_id                         Y19001 Y19004 Y29001 Y29002 Y29003 Y29004  \
# vid
# 000330ad1f424114719b7525f400660b    NaN    NaN    NaN    NaN    NaN    NaN
# 000381f0069cbf7537e6aac8923034ae    NaN    NaN    NaN    NaN    NaN    NaN
# 0003848ebd8d8163603760d53d975693    NaN    NaN    NaN    NaN    NaN    NaN
# 000401cbf304d5a8bd862a81bacfa494    NaN    NaN    NaN    NaN    NaN    NaN
# 00044a586c249c05f0969e45ef03ab9d    NaN    NaN    NaN    NaN    NaN    NaN
#
# table_id                         Y29005 Y29021 Y29058 Y79001
# vid
# 000330ad1f424114719b7525f400660b    NaN    NaN    NaN    NaN
# 000381f0069cbf7537e6aac8923034ae    NaN    NaN    NaN    NaN
# 0003848ebd8d8163603760d53d975693    NaN    NaN    NaN    NaN
# 000401cbf304d5a8bd862a81bacfa494    NaN    NaN    NaN    NaN
# 00044a586c249c05f0969e45ef03ab9d    NaN    NaN    NaN    NaN
#
# [5 rows x 2795 columns]

# %%
data_fmt_all.reset_index(inplace=True)
data_fmt_all.head()
# Out:
# table_id                               vid 004997  \
# 0         000330ad1f424114719b7525f400660b    NaN
# 1         000381f0069cbf7537e6aac8923034ae    NaN
# 2         0003848ebd8d8163603760d53d975693    NaN
# 3         000401cbf304d5a8bd862a81bacfa494    NaN
# 4         00044a586c249c05f0969e45ef03ab9d    NaN
#
# table_id                                               0101  \
# 0         双侧甲状腺大小形态正常，包膜光整，实质回声均匀，光点稍粗，未见明显异常回声。CDFI：血流显...
# 1                                                       NaN
# 2         双侧乳腺腺体层增厚,内部结构紊乱,回声不均，未见异常血流。$双侧甲状腺大小形态正常，包膜尚完...
# 3         双侧乳腺腺体层轻度增厚,内部结构稍紊乱,回声欠均匀，CDFI：未见异常血流。$双侧甲状腺形态...
# 4         双侧乳腺腺体层增厚,内部结构紊乱,回声不均，右侧内可见一低回声区，范围约21×15mm，边界...
#
# table_id                                               0102 0104 0105 0106  \
# 0         甲状腺彩超（含颈部淋巴细胞）未发现明显异常$前列腺:前列腺稍大膀胱、双侧输尿管未发现明显异常...  NaN  NaN  NaN
# 1         左肾、右肾、膀胱、双侧输尿管未发现明显异常$子宫:绝经后子宫左附件、右附件未发现明显异常$肝...  NaN  NaN  NaN
# 2         左肾、右肾、膀胱、双侧输尿管未发现明显异常$双侧乳腺小叶增生$甲状腺双叶回声不均匀,建议甲功...  NaN  NaN  NaN
# 3         肝:脂肪肝（轻度）胆、胰、脾、左肾、右肾未发现明显异常$双侧乳腺轻度增生$子宫:宫颈囊肿（多...  NaN  NaN  NaN
# 4         双侧乳腺小叶增生右乳腺低回声区，考虑结节,建议医院进一步检查$肝、胆、胰、脾未发现明显异常$...  NaN  NaN  NaN
#
# table_id 0107 0108 0109  ...   Y19001 Y19004 Y29001 Y29002 Y29003 Y29004  \
# 0         NaN  NaN  NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 1         NaN  NaN  NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 2         NaN  NaN  NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 3         NaN  NaN  NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN
# 4         NaN  NaN  NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN
#
# table_id Y29005 Y29021 Y29058 Y79001
# 0           NaN    NaN    NaN    NaN
# 1           NaN    NaN    NaN    NaN
# 2           NaN    NaN    NaN    NaN
# 3           NaN    NaN    NaN    NaN
# 4           NaN    NaN    NaN    NaN
#
# [5 rows x 2796 columns]

# %%
data_fmt_all.to_csv('../tmp/data_fmt_all.csv', index=False, encoding='utf-8')

# %%
data_fmt_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57298 entries, 0 to 57297
# Columns: 2796 entries, vid to Y79001
# dtypes: object(2796)
# memory usage: 1.2+ GB

# %%
# # 缺失值统计
# null_count = data_fmt_all.isnull().sum()
# print(len(null_count[null_count<50000]))
# # 256 缺失值少于50000的特征只有256个..

# %%
# # 删除缺失值过多的数据
# data_keep_50000 = data_fmt_all .drop(labels=null_count [null_count >=50000].index,axis=1)
# data_keep_50000 .to_csv("data_keep_50000.csv")

# %%
def getFeatureInfo(i, df, n=20):
    '''
        展示指定行、或者指定字段的信息：unique_list，null_count
       Params:
       ---------------
       i  : int or str : 特征索引或者名称
       n : 展示前n个属性
       df ： 指定的DataFrame

       e.g.:
       --------------
       getFeatureInfo(0, data_fmt_all)
       getFeatureInfo('0102', data_fmt_all)
    '''    
    if isinstance(i, int):
        col = df.columns[i]
        f = df.iloc[:,i]
    else:
        col = i
        f = df[i]
    f_u = pd.unique(f)    
    print("Feature \t:\t",col)
    print("Types \t\t:\t",len(f_u))
    print("Null Count \t:\t",pd.isnull(f).sum())
    print("Value Counts :")
    print("---------------------")
    print(pd.value_counts(f).sort_values(ascending=False)[:n])
